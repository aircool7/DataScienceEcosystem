# %%
# Excercise 1: Create a Jypiter Notebook

# %% [markdown]
# ## Exercise 1: Create a Jupyter Notebook
#
# ![image.png](attachment:fe096d03-f96e-4a3d-bd7a-bcd88ba6e39e.png)

# %%
# Excercise 2: Create a Markdown cell with the tittle of the notebook

# %% [markdown]
# ![image.png](attachment:406a21f6-043c-4e99-bcd6-61cef0d01503.png)

# %% [markdown]
# # Data Science Tools and Ecosystems

# %%
#Excercise 3: Create a markdown cell for an introduction

# %% [markdown]
# ![image.png](attachment:265fdf7e-0081-40c9-bbf9-d752d97bee5e.png)

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystems are summarized.

# %%
#Excercise 4: Create a markdown cell to list data science languages

# %% [markdown]
# ![image.png](attachment:e63a255b-3b96-45dd-b176-aee8bbe427bf.png)

# %% [markdown]
# # Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. R
# 4. Scala

# %%
# Excercise 5 - Create a markdown cell to list data science libraries

# %% [markdown]
# ![image.png](attachment:6bad1639-c915-4781-a791-1c18637a6e05.png)

# %% [markdown]
# # Some of the comply used libraries used by Data Scientists include:
# 1. Scikit
# 2. NumPy
# 3. Scientific Computing
# 4. Python Visualization
# 5. High-Level-Machine Learning

# %%
# Excercise 6 - Create a markdown cell with a table of Data Science tools

# %% [markdown]
# ![image.png](attachment:954f66f1-9bc8-45ad-85f6-d8c73e0bed22.png)

# %% [markdown]
# # Data Science Tools
# | Data Science Tools |
# | ----------------- |
# | RStudio |
# | GitHub |
# | GitLab |

# %%
# Excercise 7 - Create a markdown cell introducing arithmethic expression examples

# %% [markdown]
# ![image.png](attachment:62f29a5c-52b4-4ca6-931c-08d79a6c5919.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# Excercise 8 - Create a code cell to multiply and add numbers

# %% [markdown]
# ![image.png](attachment:870c2872-65ef-43be-8a99-c041641b0f6b.png)

# %%
#This is a simple arithmetic expression to multiply and add integers
(3*4)+5
# Out:
# 17

# %%
# Excercise 9 - Create a code cell to convert

# %% [markdown]
# ![image.png](attachment:4334163a-ced3-4e0d-aa6c-de46d4810873.png)

# %%
# This will convert 200 minutes to hours by dividing by 60
(200/60)
# Out:
# 3.3333333333333335

# %%
# Excercise 10 - Insert a markdown cell to list Objectives

# %% [markdown]
# ![image.png](attachment:b78380d1-9422-4480-8346-61e530042b23.png)

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystems are summarized.

# %% [markdown]
# **Objectives:**

# %% [markdown]
# - List popular languages for Data Science
# - List commonly used libraries for Data Scientists
# - List commonly used tools for Data Scientists

# %%
# Excercise 11 - Create a markdown cell to indicate the Author's name

# %% [markdown]
# ![image.png](attachment:34fc3689-ca64-4004-bd36-e7d05823d8fb.png)

# %% [markdown]
# ## Author
# Axel Gonzalez

# %%
# Excercise 12 - Share your notebook through GitHub

# %% [markdown]
# ![image.png](attachment:6ea0903c-8c3d-4792-aa50-4c729fed8e53.png)
